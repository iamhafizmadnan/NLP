# %% [markdown]
# # Lecture 5: Document Loader --- Ingesting Data
#
# - **Course** : NLP with Langchain
# ___
#
# ## The Big Picture
# Imagine you are building an AI assistant for bookstore . Your data lives everywhere:
#
# - Product catalog in a **CSV** file
# - Book summaries in **PDF** files
# - Customer reviews in a **text** file
# - Author bias in **website**
#
#
# How do you feel ALL of this into your AI assistant?Your need a **Document Loader** to ingest data from various sources and formats into a structured format that your AI can understand and use effectively.
#
#
# ### What you will learn in this lecture:
#
#
# | # | Topic | Real-world Analogy |
# |---|-------|--------------------|
# |1  | Document Objects | The "Universal Shipping box" for all data |
# |2 | Text & PDF Loaders | Reading books and documents |
# |3 | CSV Loaders | Reading spreadsheets with row by row |
# |4 | Web Loader | Grabbing into from websites |
# |5 | Cloud Loaders | Connecting to google drive You Tube etc.|
# |6 | Hands on Experience | Build it yourself! |
#
#
#
# ___

# %% [markdown]
# # 0. Enivronment Setup
# Run this cell once to install the package we'll need today.
# If you have already installed it, you can skip this step.

# %%
# install the required package
# %pip install langchain langchain-community pypdf beautifulsoup4 lxml
# Out:
# Requirement already satisfied: langchain in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-community in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (0.4.1)
# Requirement already satisfied: pypdf in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (6.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (4.14.3)
# Requirement already satisfied: lxml in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (6.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain) (1.2.26)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.25)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\mk\miniconda3\envs\nlp\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.documents import Document

# lets create a document manually to see what it looks like
sample_doc = Document(
    page_content = 'Langchain makes it easy to build AI apps',
    metadata = {
        'source': 'manual creation',
        'page': 0,
        'author': 'Hafiz Adnan Sami'

    }
)

# Print what's inside our document
print(f"Content: {sample_doc.page_content}")
print(f"Metadata: {sample_doc.metadata}")
print(f"Type: {type(sample_doc)}")
# Out:
# Content: Langchain makes it easy to build AI apps
# Metadata: {'source': 'manual creation', 'page': 0, 'author': 'Hafiz Adnan Sami'}
# Type: <class 'langchain_core.documents.base.Document'>

# %%
# you can access metadata fields individually as well
source = sample_doc.metadata.get('source', 'unknown ')
page_number = sample_doc.metadata.get('page', -1)
author = sample_doc.metadata.get('author', 'N / A')


print(f"Source: {source}")
print(f"Page Number: {page_number}")
print(f"Author: {author}")
# Out:
# Source: manual creation
# Page Number: 0
# Author: Hafiz Adnan Sami

# %% [markdown]
# # 2. TextLoader --- Reading plain text files
# The simplest loader. It reads a text file and wrap it in a Document object.
#
# Think of it as : "Reading a book and putting it in a box for the AI to use later"
#
# **Best for**: Plain text files, logs, transcripts, etc.

# %%
from langchain_community.document_loaders import TextLoader

# step1 : create a text file with some content (tell it which files to read)
text_loader = TextLoader(
    file_path=r"E:\NLP\nlp.txt",
    encoding='utf-8',
    
)

# step2 : load the document
documents = text_loader.load()

# step3 : print the loaded document
print(f"Loaded documents: {len(documents)}")
print(f"\n--- The Text File Content ---\n")
print(documents[0].page_content)
print(f"\n--- Metadata ---\n")
print(documents[0].metadata)
# Out:
# Loaded documents: 1
#
# --- The Text File Content ---
#
# Introduction to Natural Language Processing
# Natural Language Processing (NLP) is a subfield of Artificial Intelligence that focuses on the interaction between computers and human language. The goal of NLP is to enable machines to understand, interpret, and generate human language in a valuable way.
# NLP combines computational linguistics with machine learning and deep learning techniques. It is widely used in applications such as chatbots, machine translation, sentiment analysis, and information retrieval systems.
#
# History of NLP
# The history of NLP began in the 1950s with early rule-based systems. One of the first examples was the Georgetown-IBM experiment in , which demonstrated automatic translation of Russian sentences into English.
# In the, statistical methods became popular. Researchers started using large corpora of text to train models. In recent years, deep learning approaches such as transformers have significantly improved NLP performance.
#
# Key Components of NLP
# NLP systems typically involve several important components:
# Tokenization: Breaking text into words or sentences
# Stopword Removal: Removing common words like the, is, and
#  Stemming and Lemmatization: Reducing words to their root form
#  Part-of-Speech Tagging: Identifying grammatical roles
#  Named Entity Recognition (NER): Detecting names, locations, etc.
#
#
#
# --- Metadata ---
#
# {'source': 'E:\\NLP\\nlp.txt'}

# %% [markdown]
# # 3. PDFLoader --- Reading PDF page by page
# PDFs are more complex than plain text. They can have multiple pages, images, and different layouts. The PDFLoader reads each page and creates a Document object for each one.
#
# **Analogy**: If TextLoader reads a whole notebook at once , PyPDFLoader reads tears out each page and gives it to you one by one.
#
# **Best for**: PDF documents, research papers, reports, etc.

# %%
from langchain_community.document_loaders import PyPDFLoader

# step1 : create a PDF loader (tell it which PDF file to read)
pdf_loader = PyPDFLoader(
    file_path=r"E:\NLP\Introduction to Natural Language Processing.pdf"
)
# step2 : load the PDF document
pdf_documents = pdf_loader.load()

# step3 : print the loaded PDF documents
print(f"Loaded PDF documents: {len(pdf_documents)}")
print(f"\n--- PDF Content ---\n")

for index , doc in enumerate(pdf_documents):
    print(f"Page {index + 1}:\n{doc.page_content}\n")
    print(f"Metadata: {doc.metadata}\n")
# Out:
# Loaded PDF documents: 3
#
# --- PDF Content ---
#
# Page 1:
# Introduction to Natural Language Processing
# Natural Language Processing (NLP) is a subfield of Artificial Intelligence that focuses on the
# interaction between computers and human language. The goal of NLP is to enable machines to
# understand, interpret, and generate human language in a valuable way.
# NLP combines computational linguistics with machine learning and deep learning techniques. It
# is widely used in applications such as chatbots, machine translation, sentiment analysis, and
# information retrieval systems.
#
# History of NLP
# The history of NLP began in the 1950s with early rule-based systems. One of the first examples
# was the Georgetown-IBM experiment in 1954, which demonstrated automatic translation of
# Russian sentences into English.
# In the 1980s, statistical methods became popular. Researchers started using large corpora of text
# to train models. In recent years, deep learning approaches such as transformers have significantly
# improved NLP performance.
#
# Key Components of NLP
# NLP systems typically involve several important components:
# Tokenization: Breaking text into words or sentences
# Stopword Removal: Removing common words like “the”, “is”, “and”
# Stemming and Lemmatization: Reducing words to their root form
# Part-of-Speech Tagging: Identifying grammatical roles
# Named Entity Recognition (NER): Detecting names, locations, etc.
#
# Metadata: {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-04-07T19:19:51+05:00', 'author': 'Moorche', 'moddate': '2026-04-07T19:19:51+05:00', 'source': 'E:\\NLP\\Introduction to Natural Language Processing.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
#
# Page 2:
# Applications of NLP
# NLP is used in many real-world applications:
# 1. Chatbots and Virtual Assistants
# Systems like customer support bots use NLP to understand user queries.
# 2. Machine Translation
# Tools like Google Translate convert text from one language to another.
# 3. Sentiment Analysis
# Companies analyze customer reviews to understand opinions.
# 4. Speech Recognition
# Converting spoken language into text.
#
# Challenges in NLP
# Despite its progress, NLP still faces several challenges:
# Understanding context and ambiguity
# Handling multiple languages
# Dealing with slang and informal text
# Processing large-scale data efficiently
#
# Future of NLP
# The future of NLP is promising. With advancements in large language models, systems are
# becoming more accurate and human-like. Researchers are working on improving reasoning,
# reducing bias, and making AI systems more explainable.
#
# Sample Paragraph for Testing
# The quick brown fox jumps over the lazy dog. This sentence is often used to test typing systems
# and font displays. In NLP, such sentences can be used for tokenization and parsing experiments.
# Another example sentence is: “Artificial Intelligence is transforming the world rapidly.” This can
# be used for sentiment analysis or keyword extraction tasks.
#
# Metadata: {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-04-07T19:19:51+05:00', 'author': 'Moorche', 'moddate': '2026-04-07T19:19:51+05:00', 'source': 'E:\\NLP\\Introduction to Natural Language Processing.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}
#
# Page 3:
#
#
# Metadata: {'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-04-07T19:19:51+05:00', 'author': 'Moorche', 'moddate': '2026-04-07T19:19:51+05:00', 'source': 'E:\\NLP\\Introduction to Natural Language Processing.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}
